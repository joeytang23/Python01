# %%
import pandas as pd

#构造DATa frame--学员成绩信息
df = pd.DataFrame([
    {"姓名":"小王","语文":90,"数学":80,"英语":70},
    {"姓名":"小李","语文":80,"数学":70,"英语":60},
    {"姓名":"小张","语文":70,"数学":60,"英语":50},
    {"姓名":"小赵","语文":60,"数学":50,"英语":40},
    {"姓名":"小孙","语文":50,"数学":40,"英语":30},
    {"姓名":"小周","语文":40,"数学":30,"英语":20},
    {"姓名":"小吴","语文":30,"数学":20,"英语":10},
    {"姓名":"小郑","语文":20,"数学":10,"英语":0}

]

)
#series就是dataframe里面的一列
df
#统计计算
f"语文最高分:{df['语文'].max()},最低分:{df['语文'].min()},平均分:{df['语文'].mean()}"
f"数学最高分:{df['数学'].max()},最低分:{df['数学'].min()},平均分:{df['数学'].mean()}"
f"英语最高分:{df['英语'].max()},最低分:{df['英语'].min()},平均分:{df['英语'].mean()}"
f""
# Out:
# '语文最高分:55.0,最低分:45.0,35.0'
